# %% [markdown]
# <a href="https://colab.research.google.com/github/Utsuk7/Football-Analysis/blob/main/Football_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.7/802.7 kB 3.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uuP8raeeCTrDPyur6dRI")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-3 in yolov5pytorch:: 100%|██████████| 522/522 [00:00<00:00, 2800.67it/s]

# %%
url=dataset.location

# %%
import shutil

shutil.move('/content/football-players-detection-3/train','/content/football-players-detection-3/football-players-detection-3/train')

shutil.move('/content/football-players-detection-3/test','/content/football-players-detection-3/football-players-detection-3/test')

shutil.move('/content/football-players-detection-3/valid','/content/football-players-detection-3/football-players-detection-3/valid')
# Out:
# '/content/football-players-detection-3/football-players-detection-3/valid'

# %%
model=YOLO('yolov5xu.pt')
# Out:
# ...
# 100%|██████████| 186M/186M [00:00<00:00, 369MB/s]

# %%
# !yolo task=detect mode=train model=yolov5xu.pt data='/content/football-players-detection-3/data.yaml' epochs=100 imgsz=500
# Out:
# Ultralytics YOLOv8.2.58 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
result=model.predict('/content/86.mp4',save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3908) /content/86.mp4: 288x512 9 players, 1 referee, 110.6ms
# video 1/1 (frame 2/3908) /content/86.mp4: 288x512 11 players, 1 referee, 48.3ms
# video 1/1 (frame 3/3908) /content/86.mp4: 288x512 7 players, 2 referees, 48.3ms
# video 1/1 (frame 4/3908) /content/86.mp4: 288x512 4 players, 1 referee, 47.5ms
# video 1/1 (frame 5/3908) /content/86.mp4: 288x512 3 players, 30.6ms
# ...

# %%
# !cp /content/runs/detect/predict/86.avi /content/drive/MyDrive/Football_Analysis_Video.avi
